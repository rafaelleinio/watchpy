# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from copy import copy, deepcopy

def limites (n, minn = 0, maxn = 255): #coloca range de números entre 0 e 255
    return max(min(maxn, n), minn)

# %%
brain = cv2.imread("foo.jpg",0)
plt.figure()
plt.imshow(brain,cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
def crop_image(image, x, y, offset):
    return[line[x - offset : x + offset - 1] for line in image[y - offset: y + offset - 1]]

plt.figure()
plt.imshow(crop_image(brain,250, 300,100),cmap='gray', vmin=0, vmax=255)
plt.show()
