# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from copy import copy, deepcopy

def limites (n, minn = 0, maxn = 255): #coloca range de números entre 0 e 255
    return max(min(maxn, n), minn)

# %%
brain = cv2.imread("foo.jpg",0)
plt.figure()
plt.imshow(brain,cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
def crop_image(image, x, y, offset):
    #return [list(filter(lambda p: (abs(x - p[0]) < offset) and (abs(y - p[1]) < offset), line)) for y, line in enumerate(image)]
    return[line for j, line in enumerate(image) if abs(j - y) < offset ]
plt.figure()
plt.imshow(crop_image(brain,0,0,0),cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-81dbf34c9a22> in <module>()
#       3
#       4 plt.figure()
# ----> 5 plt.imshow(crop_image(brain,0,0,0),cmap='gray', vmin=0, vmax=255)
#       6 plt.show()
#
# <ipython-input-7-81dbf34c9a22> in crop_image(image, x, y, offset)
#       1 def crop_image(image, x, y, offset):
# ----> 2     return [list(filter(lambda p: (abs(x - p[0]) < offset) and (abs(y - p[1]) < offset), line)) for line in image]
#       3
#       4 plt.figure()
#       5 plt.imshow(crop_image(brain,0,0,0),cmap='gray', vmin=0, vmax=255)
#
# <ipython-input-7-81dbf34c9a22> in <listcomp>(.0)
#       1 def crop_image(image, x, y, offset):
# ----> 2     return [list(filter(lambda p: (abs(x - p[0]) < offset) and (abs(y - p[1]) < offset), line)) for line in image]
#       3
#       4 plt.figure()
# ...

# %%
brain[0]
# Out:
# array([112, 113, 113, 114, 115, 116, 118, 118, 112, 115, 115, 112, 110,
#        112, 114, 114, 115, 115, 116, 116, 116, 116, 117, 118, 114, 114,
#        113, 113, 113, 113, 113, 113, 108, 109, 110, 111, 112, 112, 111,
#        111, 114, 114, 113, 113, 112, 111, 111, 111, 116, 117, 116, 115,
#        114, 114, 115, 117, 116, 116, 115, 114, 114, 114, 115, 115, 112,
#        111, 109, 109, 110, 110, 109, 109, 112, 111, 110, 109, 109, 110,
#        111, 112, 112, 110, 109, 111, 110, 108, 108, 110, 111, 111, 112,
#        113, 114, 114, 115, 115, 111, 111, 111, 111, 110, 110, 112, 113,
#        110, 110, 110, 110, 110, 110, 110, 110, 112, 112, 112, 112, 112,
#        113, 113, 114, 110, 110, 110, 109, 109, 110, 110, 110, 109, 109,
#        109, 109, 110, 111, 113, 114, 112, 111, 109, 108, 108, 109, 111,
#        112, 104, 105, 107, 108, 109, 110, 110, 109, 112, 111, 110, 108,
#        108, 108, 108, 109, 108, 110, 111, 109, 105, 105, 108, 112, 112,
# ...
